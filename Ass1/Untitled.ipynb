# %%
import pandas as pd
import math
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data = pd.read_csv('21.csv')

# %%
data
# Out:
#          No.       Time        Source     Destination Protocol  Length  \
# 0         40   0.000109  10.100.102.6   216.58.204.10  TLSv1.2    8268
# 1         41   0.000109  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 2         44   0.000285  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 3         45   0.000289  10.100.102.6   216.58.204.10  TLSv1.2    8268
# 4         46   0.000336  10.100.102.6   216.58.204.10  TLSv1.2    8268
# ...      ...        ...           ...             ...      ...     ...
# 28050  98209  61.382816  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 28051  98212  61.383000  10.100.102.6   216.58.204.10  TLSv1.2    8268
# 28052  98213  61.383010  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 28053  98219  61.386593  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 28054  98220  61.386613  10.100.102.6   216.58.204.10  TLSv1.2    8268
#
#                    Info
# 0      Application Data
# 1      Application Data
# 2      Application Data
# ...

# %%
data['floored_time'] = data['Time'].apply(math.floor
                                         )

# %%
data
# Out:
#          No.       Time        Source     Destination Protocol  Length  \
# 0         40   0.000109  10.100.102.6   216.58.204.10  TLSv1.2    8268
# 1         41   0.000109  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 2         44   0.000285  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 3         45   0.000289  10.100.102.6   216.58.204.10  TLSv1.2    8268
# 4         46   0.000336  10.100.102.6   216.58.204.10  TLSv1.2    8268
# ...      ...        ...           ...             ...      ...     ...
# 28050  98209  61.382816  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 28051  98212  61.383000  10.100.102.6   216.58.204.10  TLSv1.2    8268
# 28052  98213  61.383010  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 28053  98219  61.386593  10.100.102.6  216.58.210.234  TLSv1.2    8268
# 28054  98220  61.386613  10.100.102.6   216.58.204.10  TLSv1.2    8268
#
#                    Info  floored_time
# 0      Application Data             0
# ...

# %%
plt.figure(1)
data[['Protocol','floored_time']].groupby('floored_time').Protocol.nunique().plot()
# Out:
# <img src="data:image/png;base64,..." width="701.6">
# <AxesSubplot:xlabel='floored_time'>

# %%
data = pd.read_csv('22.csv')

# %%
data
# Out:
#          No.       Time          Source   Destination Protocol  Length  \
# 0       1473   2.095884  74.125.143.189  10.100.102.6      UDP      67
# 1       1570   2.190812      62.0.80.15  10.100.102.6      UDP      71
# 2       1571   2.190812      62.0.80.15  10.100.102.6      UDP    1392
# 3       1572   2.190812      62.0.80.15  10.100.102.6      UDP    1392
# 4       1573   2.190812      62.0.80.15  10.100.102.6      UDP    1392
# ...      ...        ...             ...           ...      ...     ...
# 18638  97744  60.947533      62.0.80.15  10.100.102.6      UDP    1392
# 18639  97745  60.947533      62.0.80.15  10.100.102.6      UDP    1392
# 18640  97746  60.947533      62.0.80.15  10.100.102.6      UDP    1392
# 18641  97747  60.947533      62.0.80.15  10.100.102.6      UDP    1011
# 18642  97767  60.956452      62.0.80.15  10.100.102.6      UDP      68
#
#                          Info
# 0        443  >  64707 Len=25
# 1        443  >  55185 Len=29
# ...

# %%
data['floored_time'] = data['Time'].apply(math.floor
                                         )

# %%
data[data['Protocol']=='UDP'][['Length','floored_time']].groupby('floored_time').sum('length').plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='floored_time'>

# %%
data = pd.read_csv('23.csv')

# %%
data
# Out:
#       No.       Time        Source   Destination Protocol  Length  \
# 0    5064   4.648748  10.100.102.1  10.100.102.6      DNS     394
# 1   10130  10.635359  10.100.102.1  10.100.102.6      DNS     346
# 2   10145  10.653618  10.100.102.1  10.100.102.6      DNS     104
# 3   11470  12.467741  10.100.102.1  10.100.102.6      DNS     389
# 4   14518  15.283323  10.100.102.1  10.100.102.6      DNS     323
# ..    ...        ...           ...           ...      ...     ...
# 73  88585  55.449106  10.100.102.1  10.100.102.6      DNS     388
# 74  88815  55.590308  10.100.102.1  10.100.102.6      DNS     357
# 75  89231  55.754667  10.100.102.1  10.100.102.6      DNS     326
# 76  89375  55.773599  10.100.102.1  10.100.102.6      DNS     326
# 77  95413  60.115501  10.100.102.1  10.100.102.6      DNS     367
#
#                                                  Info
# 0   Standard query response 0x9261 A events.browsi...
# 1   Standard query response 0xbc01 A ssl.gstatic.c...
# ...

# %%
data['floored_time'] = data['Time'].apply(math.floor
                                         )

# %%
data[['Protocol','floored_time']].groupby('floored_time').count().plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='floored_time'>

# %%
data = pd.read_csv('24.csv')

# %%
data
# Out:
#          No.       Time         Source   Destination Protocol  Length  \
# 0          5   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 1          6   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 2          7   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 3         10   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 4         12   0.000000  216.58.204.10  10.100.102.6      TCP      60
# ...      ...        ...            ...           ...      ...     ...
# 12942  98188  61.351980  216.58.204.10  10.100.102.6      TCP      60
# 12943  98189  61.351980  216.58.204.10  10.100.102.6      TCP      60
# 12944  98211  61.382942  216.58.204.10  10.100.102.6      TCP      60
# 12945  98214  61.386495  216.58.204.10  10.100.102.6      TCP      60
# 12946  98218  61.386533  216.58.204.10  10.100.102.6      TCP      60
#
#                                                     Info
# 0         443  >  54564 [ACK] Seq=1 Ack=1 Win=8349 Len=0
# ...

# %%
data['floored_time'] = data['Time'].apply(math.floor
                                         )

# %%
plt.figure(5)
data[['Destination','floored_time']].groupby('floored_time').Destination.nunique().plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='floored_time'>

# %%
data
# Out:
#          No.       Time         Source   Destination Protocol  Length  \
# 0          5   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 1          6   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 2          7   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 3         10   0.000000  216.58.204.10  10.100.102.6      TCP      60
# 4         12   0.000000  216.58.204.10  10.100.102.6      TCP      60
# ...      ...        ...            ...           ...      ...     ...
# 12942  98188  61.351980  216.58.204.10  10.100.102.6      TCP      60
# 12943  98189  61.351980  216.58.204.10  10.100.102.6      TCP      60
# 12944  98211  61.382942  216.58.204.10  10.100.102.6      TCP      60
# 12945  98214  61.386495  216.58.204.10  10.100.102.6      TCP      60
# 12946  98218  61.386533  216.58.204.10  10.100.102.6      TCP      60
#
#                                                     Info  floored_time
# ...

# %%
data = pd.read_csv('25.csv')

# %%
data[(data['Protocol']=='TCP') | (data['Protocol']=='UDP') |(data['Protocol']=='DNS')]
# Out:
#          No.       Time          Source   Destination Protocol  Length  \
# 0          1   0.000000  216.58.210.234  10.100.102.6      TCP      60
# 1          2   0.000000  216.58.210.234  10.100.102.6      TCP      60
# 2          3   0.000000  216.58.210.234  10.100.102.6      TCP      60
# 3          4   0.000000  216.58.210.234  10.100.102.6      TCP      60
# 4          5   0.000000   216.58.204.10  10.100.102.6      TCP      60
# ...      ...        ...             ...           ...      ...     ...
# 98214  98215  61.386495  216.58.210.234  10.100.102.6      TCP      60
# 98215  98216  61.386495  216.58.210.234  10.100.102.6      TCP      60
# 98216  98217  61.386495  216.58.210.234  10.100.102.6      TCP      60
# 98217  98218  61.386533   216.58.204.10  10.100.102.6      TCP      60
# 98220  98221  61.388501  216.58.210.234  10.100.102.6      TCP      60
#
#                                                     Info
# 0         443  >  54877 [ACK] Seq=1 Ack=1 Win=7915 Len=0
# ...

# %%
data['floored_time'] = data['Time'].apply(math.floor
                                         )

# %%
udp=data[data['Protocol']=='UDP'][['Length','floored_time']].groupby('floored_time').sum('length')

# %%
tcp = data[data['Protocol']=='TCP'][['Length','floored_time']].groupby('floored_time').sum('length')

# %%
dns = data[data['Protocol']=='DNS'][['Length','floored_time']].groupby('floored_time').sum('length')

# %%
import matplotlib.pyplot as plt
plt.figure(6)
plt.plot(udp,label='udp')
plt.plot(tcp,label='tcp')
plt.plot(dns,label='dns')

plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(7)
plt.plot(dns,label='dns')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(8)
plt.plot(tcp,label='tcp')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure(9)
plt.plot(udp,label='udp')
# Out:
# <img src="data:image/png;base64,..." width="640">
